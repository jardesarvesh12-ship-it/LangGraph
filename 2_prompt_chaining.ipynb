# %% [markdown]
# - Sequential Prompt Chaning Workflow
#
# TOPIC: provide  a topic to llm and llm can genrate a Blog

# %%
from langgraph.graph import StateGraph, START, END
from langchain_huggingface import ChatHuggingFace

from typing import TypedDict

from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEndpoint

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
,  # Or another model of your choice
    task="text-generation",
    max_new_tokens=512
)
model = ChatHuggingFace(llm=llm)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**Title:** "The Rise of AI in India: Transforming Industries and Revolutionizing Lives"\n\n**I. Introduction**\n\n* Brief background on AI and its global impact\n* Importance of AI in India\'s economy and society\n* Thesis statement: AI is transforming India\'s industries and revolutionizing lives, and it\'s essential to understand the opportunities and challenges it presents.\n\n**II. Current State of AI in India**\n\n* Overview of AI adoption in India: government initiatives, startups, and large corporations\n* Key sectors where AI is being applied, such as healthcare, finance, and education\n* Statistics on AI adoption in India: market size, growth rate, and user base\n\n**III. Industries Impacted by AI in India**\n\n* 1. Healthcare:\n\t+ Applications of AI in medical diagnosis, treatment, and patient care\n\t+ Success stories of AI-based healthcare startups in India\n* 2. Finance:\n\t+ AI-powered chatbots and virtual assistants in banking and insurance\n\t+ Automated trading and financial analysis\n* 3. Education:\n\t+ AI-based learning platforms and personalized education\n\t+ AI-assisted teacher training and evaluation\n* 4. Manufacturing:\n\t+ Industrial automation and predictive maintenance\n\t+ AI-powered quality control and supply chain management\n\n**IV. Challenges and Concerns**\n\n* Data privacy and security concerns\n* Ethical considerations in AI development and deployment\n* Job displacement and re-skilling of workers\n* Regulatory framework and government support for AI adoption\n\n**V. Opportunities and Future Prospects**\n\n* Emerging applications of AI in India, such as:\n\t+ Smart cities and infrastructure\n\t+ Cybersecurity\n\t+ Environmental monitoring and conservation\n* Role of AI in improving governance, citizen services, and social welfare\n* International collaborations and partnerships for AI research and development\n\n**VI. Conclusion**\n\n* Recap of the impact of AI in India and its growing importance\n* Call to action: Encouragement for readers to adopt AI and stay updated on its developments\n* Final thoughts: AI\'s potential to transform India\'s future, and the need for a collaborative effort to harness its benefits.\n\nThis outline should provide a good structure for your blog post on the "Rise of AI in India". Good luck with your writing!', 'content': "**The Rise of AI in India: Transforming Industries and Revolutionizing Lives**\n\nIndia, one of the world's fastest-growing economies, is at the cusp of a technological revolution. Artificial Intelligence (AI) is transforming industries and revolutionizing lives, and it's essential to understand the opportunities and challenges it presents. In this blog post, we'll delve into the current state of AI in India, its impact on various industries, challenges and concerns, and future prospects.\n\n**I. Introduction**\n\nArtificial Intelligence has been making waves globally, with its applications ranging from smart homes to self-driving cars. The Indian government has recognized the potential of AI to drive economic growth and improve the quality of life. With the government's initiatives, startups, and large corporations, AI is transforming India's economy and society. In this blog post, we'll explore the rise of AI in India and its transformative power.\n\n**II. Current State of AI in India**\n\nIndia is home to a thriving AI ecosystem, with various government initiatives, startups, and large corporations driving adoption. The Indian government has launched several initiatives to promote AI, including the National Policy on Artificial Intelligence, which aims to create a robust AI framework. Startups like Vedant Fowle's startup, SigTuple, are using AI to improve healthcare outcomes, while large corporations like TCS and Infosys are investing heavily in AI research and development. According to a report by ResearchAndMarkets. ...

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Transforming Industries and Revolutionizing Lives**
#
# India, one of the world's fastest-growing economies, is at the cusp of a technological revolution. Artificial Intelligence (AI) is transforming industries and revolutionizing lives, and it's essential to understand the opportunities and challenges it presents. In this blog post, we'll delve into the current state of AI in India, its impact on various industries, challenges and concerns, and future prospects.
#
# **I. Introduction**
#
# Artificial Intelligence has been making waves globally, with its applications ranging from smart homes to self-driving cars. The Indian government has recognized the potential of AI to drive economic growth and improve the quality of life. With the government's initiatives, startups, and large corporations, AI is transforming India's economy and society. In this blog post, we'll explore the rise of AI in India and its transformative power.
#
# **II. Current State of AI in India**
#
# India is home to a thriving AI ecosystem, with various government initiatives, startups, and large corporations driving adoption. The Indian government has launched several initiatives to promote AI, including the National Policy on Artificial Intelligence, which aims to create a robust AI framework. Startups like Vedant Fowle's startup, SigTuple, are using AI to improve healthcare outcomes, while large corporations like TCS and Infosys are investing heavily in AI research and development. According to a report by ResearchAndMarkets.com, India's AI market is expected to reach $4.8 billion by 2024, growing at a Compound Annual Growth Rate (CAGR) of 44.3%.
#
# **III. Industries Impacted by AI in India**
#
# AI is transforming various industries in India, including:
#
# * **Healthcare:** AI is being used to improve medical diagnosis, treatment, and patient care. For instance, AI-powered diagnostic tools can analyze medical images and identify diseases more accurately than human doctors. SigTuple, a startup, is using AI to analyze medical samples and provide insights to doctors, improving patient outcomes.
# * **Finance:** AI-powered chatbots and virtual assistants are revolutionizing banking and insurance. For instance, banks like ICICI and Axis are using AI-powered chatbots to provide customers with 24/7 customer support. Automated trading and financial analysis are also being used to improve investment decisions.
# * **Education:** AI-based learning platforms and personalized education are transforming the way students learn. For instance, startups like BYJU's are using AI to provide personalized learning experiences to students, improving their academic performance.
# *
